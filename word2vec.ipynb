# %%
from __future__ import unicode_literals, print_function, division
import pandas as pd
import os
from io import open
import glob
import unicodedata
import string
import torch
import numpy as np
import math
from nltk.tokenize import sent_tokenize, word_tokenize 
import warnings
import pickle

warnings.filterwarnings(action = 'ignore')

import gensim 
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
import gensim.downloader as api
from gensim import utils

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cwd = '/content/drive/My Drive/nlp_project/'

# %%
def load_embeddings(path):
    embedding_map = {}
    with open(path) as f:
        for line in f:
            try:
                pieces = line.rstrip().split()
                embedding_map[pieces[0]] = [float(weight) for weight in pieces[1:]]
            except:
                pass
    return embedding_map

def my_save_word2vec_format(fname, vocab, vectors, binary=True, total_vec=2):
    if not (vocab or vectors):
        raise RuntimeError("no input")
    if total_vec is None:
        total_vec = len(vocab)
    vector_size = vectors.shape[1]
    assert (len(vocab), vector_size) == vectors.shape
    with utils.smart_open(fname, 'wb') as fout:
        print(total_vec, vector_size)
        fout.write(utils.to_utf8("%s %s\n" % (total_vec, vector_size)))
        # store in sorted order: most frequent words at the top
        for word, row in vocab.items():
            if binary:
                row = row.astype(REAL)
                fout.write(utils.to_utf8(word) + b" " + row.tostring())
            else:
                fout.write(utils.to_utf8("%s %s\n" % (word, ' '.join(repr(val) for val in row))))

d = load_embeddings(cwd + 'sgns.sogou.bigram.txt')
print('model loaded')
m = gensim.models.keyedvectors.Word2VecKeyedVectors(vector_size=300)
m.vocab = d
m.vectors = np.array(list(d.values()))
print('write to file')
my_save_word2vec_format(binary=False, fname=cwd + 'chinese_words.txt', total_vec=len(d), vocab=m.vocab, vectors=m.vectors)
print('finish')
# Out:
# model loaded
# write to file
# 364171 300
# finish

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## get word set

# %%
data = pd.read_excel(cwd + '2018 payroll.xlsx', header = None)

# %%
print(len(data))
# Out:
# 36951

# %%
word_set = set()
for i in range(len(data)):
  situation = str(data[31][i]).split() + str(data[32][i]).split()
  for w in situation:
    word_set.add(w)
print(word_set)
print(len(word_set))
# Out:
# {'等', '555', '一点', '危', '私人', '486', '1959', '见', '33', '彭', '完成', '菌', '时是', '投票', '佑', '王波', '制式', '陈惠', '会歌', '梅江', '聋', '漏', 'IT', '149', '电子科技', '1981', '住宿', '春酒', '山东', '工作日', '不分', '赠送', '尤洋', '种植', '张照', '990', '白', '字段', 'og', '会通', '闲', 'th', '385', '或', '未加', '缓和', '大部分', '小一', '程', '臣', '引导', '告', '哈', '通都', '张鑫', '过', '妍', '化', '姜海', '天安门', '审核', '铃声', '城市', '盖上', '一手', '教育科', '周一就', '34', '编码', '改变', '收起', '压缩', '筵', '流出', '修改权', '87', '控制员', '陵', '网络软件', '730', '损失', '讲', '喀什市', '那期', '华利', '用户', '算在内', 'qq', '路由器', '化学试剂', '都反', '申请号', '到时', '381', '下属', '艺', '杂音', '地方', '签完', '407', '空号', '114', '选', '；未', '英文版', '102', '731', '经销处', '时实', '木业', '长虹', '准', '中指', '仲', '费电', '负一', '种类', '上划', '打车', '都认', '回拨', 'g', '正常', '批示', '鸟', '王丽萍', '215', '让', '永康', '差距', '出错', '设立', '222', '以使', '百科', '历史记录', '昕', '额', '都加', '记录人', '51', '旧', 'as', '下回', '分别', '破解', '包装', '森', '酒店', '宾馆', '水印', '李想', '检测', '放在', '494', '悍', '发邮件', '延', '发错', '文', '大连', '十月', '试探', '涌泉', '清楚', '李如', '没', '黄林', '三九', '227', '时有时无', '翠屏区', '车牌号', '上下班', '修复', '格', '日通', '时要', '湛', '记录表', 'MB', '想着', '勾选', '相信', '外边', '值班人员', '---', '暂定', '排查', '重设', '中山市', '跟踪', '批量', '流失', '总额', 'in', '降', '让与', '威海', '庆', '不便', '295', '跨', '电力', '文件夹', '方式', '味', '新区', '中地', '按钮', '1991', '云', '坏', '插卡', '钦', '不关', '联系', '远景', '带出', '资源中心', '悬浮', '朱', '27', '911', '右侧', '下载安装', '冠', '刘荣', '套件', '成英', '霖', '做假', '自已', '韬', '个数', '企', '陈', '年前', '息', '婴幼', '溟', '具体内容', '稳定', '小数点', '104', '跳', '康威', 'bb', '戚', '拍照片', '教育培训', '会弹', '事情', '跑回', '不让', '施罗德', '来分', '463', '汤小姐', '会', '费劲', '示爱', '主要', '朗', '宋先生', '某个', '301', '社区', '接触', '空间', '不能不', '地', '300', '1531', '咨询', '偏高', '香香', '盛', '刘学', '不满', '合作伙伴', '不配', '成规', '792', '放开', '卡住', '刚改', '搞不清楚', '两手', '停机', '186', '上级领导', '不安', '都无', '顺', '字数', '瑞福祥', '截图', '失去', '程主任', '159', 'gb', '546', '执', '1861', '操作', '迟迟', '新的', '汤中', '1915', '来配', '原平', '体型', '飞飞', '之一', '志', '调过', '成无', '医', '新手机', '间隔时间', '调正', '保证数据', '9.5', '2016', '不下', '311', '星期一', '为此', 'A', '问清', '找到', '监测', '790', '出行', 'K', '88', '分隔', '财务部', '外部', '福', '7.3', '动力', '责人', '网站', '波导', '祥', '相加', '库', '义乌', '新登', '习惯', '确实', '管理软件', '339', '之内', '具体', '406', '米是', '其余', '洪先生', '硕', '请假', '都是很', '表格', '转为', '海', '658', '原石', '中国移动', '唐先生', '该人', '翼', '长大', '接线', '农业有限公司', '好友', '越南', '乐蜂', '代打', '分部', '李冰', '在手', '日数', '标注', '威威', '移动电话', '连锁店', '桌面图标', '22', '价格表', '335', '充电', '参考', '分机', '恒生', '个例', '存储空间', '处理', '库存量', '申', '销户', '服', '大厦', '时还', '啊', '苹果电脑', '都改', '907', '疑问', '219', '开网', '查阅', '时也', '美凯龙', '实际', '私聊', '群发', '二级', '中图', '吴', '供货价', '及其', '担心', '多余', '299', '云翔', '515', '288', '了', '中能', '公众', '客', '飞回', '760', '终止', '8.1', '转正', '指导思想', '于先生', '北京人', '2.0', '造成', 'cpu', '时再', '较小', '250', '临沂', '走完', '法律', '方式可', '新材料', '达', '矫情', '肿瘤医院', '帆', '变为', '56', '任意', '白纸黑字', '快件', '精密', '家教', '萍', '兴', '很早', '长春市', '算数', '012', '七八十', '回收站', '正式', '柒', '111', '1024', '断', '打的', '并建', '相对', '重装', '规划', '自称', '填', '喂喂', '送货', '呈', '来处', '生效', '都转', '153', '侯女士', '1100', '即使如此', '田先生', '垫付', '宫', '你们', '装到', '要前', '下降', '审批同意', '哼', '程序', '车载', '否则', 'IV', '纳特', '开会', '67', '泰州市', '一些', '老师', '弄好', '谨', '635', '我部', '连接点', '正', '汇总表', '发几张', '网', '05', '川', '盐化', '重新加入', '35', '弹出', 'oK', '巡', '删', '最后', 'GPS', '咱们', '置信', '晨晨', '纯', '南宁市', '算了', '济南', '南京', '0531', '瓷', '方先生', '切断', '潮', 'no', '手机软件', '空调设备', '签退', '安徽', '裂', '上级', '复', '处于', '认可', '工作人员', '登录', '第一', '英冠', '史密斯', '宜昌市', '金汉', '里加', '连', '有限', 'OF', '谷实', '彤', '成雅', '玉山镇', '看不到', '人手', '久', '格式化', '很慢', '排行表', '天利', '专门', '都是考', '1650', '545', '虚线', '区县', '合同', '收人', '莎', '雪', '总计', '听', '丁贺', '异常情况', '后地', '中客', '机制', '退掉', '再一', '米奇', '”', '车牌号码', '注意事项', '指引', '邀', '清理', '先签', '端点', '检查人员', 'U', '再加', '需求', '暂无', '星期', '收到', '清扫工', '有一天', '中心点', '国发', '具体地址', 'v', '都江堰', '发展', '源代码', '不计', '妈妈', '公司', '回来', '>', '大多', '地址栏', '东', '温迪', '头', '解析', '完人', '333', '回去', '饭', '了账', '正处', '责任', 'lg', '预防', '束', '’', 'lo', '组织', '软件', '戴女士', '890', '格洛丽亚', ...
# 8310

# %% [markdown]
# ## evaluate similarities

# %%
model = KeyedVectors.load_word2vec_format(cwd + 'chinese_words.txt', binary=False)

# %%
eval_words = ['网络','手机', '定位', '服务', '错误', '响应', '处理', '已', '华为', '在线']

eval_words_map = {}

for word in eval_words:
  eval_words_map[word] = set(model.wv.similar_by_word(word, topn=100))
  sim_word_set = set()
  for sim_word in eval_words_map[word]:
    if sim_word[0] in word_set:
      sim_word_set.add(sim_word)
  
  print(sim_word_set)
  # print(model.wv.similar_by_word(word, topn=15))
  print()
# Out:
# {('互联', 0.51678466796875), ('网络界', 0.506811797618866), ('QQ', 0.5266445279121399), ('网路', 0.5477644205093384)}
#
# {('部手机', 0.5981699228286743), ('新手机', 0.5542560815811157), ('IP', 0.5196048617362976), ('笔记本', 0.5356241464614868)}
#
# {('时间轴', 0.4591441750526428), ('定位问题', 0.44625309109687805), ('GPS', 0.4544619619846344)}
#
# {('付款方', 0.5523066520690918), ('咨询服务', 0.5665782690048218)}
#
# {('出错', 0.47132471203804016), ('说错', 0.4682994484901428), ('错误信息', 0.45625966787338257), ('选错', 0.4570876359939575), ('有误', 0.5102933645248413), ('偏差', 0.4545685052871704), ('正确', 0.5502479076385498), ('错', 0.5101631879806519), ('用错', 0.46904629468917847)}
#
# {('启动', 0.4724695682525635), ('反应', 0.40596288442611694)}
#
# {('解决', 0.4550190567970276), ('未处理', 0.4568314552307129)}
#
# {('尚未', 0.5858912467956543), ('并', 0.4743204116821289), ('已有', 0.511445939540863), ('现已', 0.7123315334320068), ('正在', 0.46389561891555786), ('一旦', 0.4568527936935425), ('都已', 0.5848924517631531), ('已将', 0.5623600482940674), ('全部', 0.44690555334091187), ('将', 0.47278380393981934), ('已是', 0.4917416572570801), ('时已', 0.4547608494758606), ('目前', 0.6010608673095703), ('台已', 0.4442528486251831), ('未', 0.44969287514686584), ('累计', 0.44415271282196045), ('已为', 0.49165916442871094), ('已经', 0.8668252229690552)}
#
# {('中兴', 0.551406741142273), ('诺基亚', 0.55613774061203), ('PC', 0.4999595880508423), ('Sun', 0.4761351943016052), ('酷派', 0.48776406049728394), ('摩托罗拉', 0.5253413915634155), ('宇龙', 0.5434404611587524), ('中国移动', 0.4769569933414459)}
#
# {('捷通', 0.4166751503944397), ('网', 0.406671941280365), ('网站', 0.40887880325317383)}

# %%
with open(cwd + 'tokenized_word_set.pickle', 'rb') as f:
    word_set = pickle.load(f)

# %%
print(type(word_set))
# Out:
# <class 'set'>

# %%
from __future__ import unicode_literals, print_function, division
import pandas as pd
import os
from io import open
import glob
import unicodedata
import string
import torch
import numpy as np
import math
from nltk.tokenize import sent_tokenize, word_tokenize 
import warnings
import pickle

warnings.filterwarnings(action = 'ignore')

import gensim 
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
import gensim.downloader as api
from gensim import utils

print(gensim.__version__)
# Out:
# 3.6.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cwd = '/content/drive/My Drive/nlp_project/'

# %%
def load_embeddings(path):
    embedding_map = {}
    with open(path) as f:
        for line in f:
            try:
                pieces = line.rstrip().split()
                embedding_map[pieces[0]] = [float(weight) for weight in pieces[1:]]
            except:
                pass
    return embedding_map

def my_save_word2vec_format(fname, vocab, vectors, binary=True, total_vec=2):
    if not (vocab or vectors):
        raise RuntimeError("no input")
    if total_vec is None:
        total_vec = len(vocab)
    vector_size = vectors.shape[1]
    assert (len(vocab), vector_size) == vectors.shape
    with utils.smart_open(fname, 'wb') as fout:
        print(total_vec, vector_size)
        fout.write(utils.to_utf8("%s %s\n" % (total_vec, vector_size)))
        # store in sorted order: most frequent words at the top
        for word, row in vocab.items():
            if binary:
                row = row.astype(REAL)
                fout.write(utils.to_utf8(word) + b" " + row.tostring())
            else:
                fout.write(utils.to_utf8("%s %s\n" % (word, ' '.join(repr(val) for val in row))))

d = load_embeddings(cwd + 'sgns.sogou.bigram.txt')
print('model loaded')
m = gensim.models.keyedvectors.Word2VecKeyedVectors(vector_size=300)
m.vocab = d
m.vectors = np.array(list(d.values()))
print('write to file')
my_save_word2vec_format(binary=False, fname=cwd + 'chinese_words.txt', total_vec=len(d), vocab=m.vocab, vectors=m.vectors)
print('finish')
# Out:
# model loaded
# write to file
# 364171 300
# finish

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## get word set

# %%
data = pd.read_excel(cwd + '2018 payroll.xlsx', header = None)

# %%
print(len(data))
# Out:
# 36951

# %%
word_set = set()
for i in range(len(data)):
  situation = str(data[31][i]).split() + str(data[32][i]).split()
  for w in situation:
    word_set.add(w)
print(word_set)
print(len(word_set))
# Out:
# {'没下', '洪先生', '没什么', '注册', 'One', 'CRM', '配合', '国庆节', '要以', '拓', '热点', '每月', '泰科', '明天', '孙鹏', '机电工程', '净增', '经常出现', '潮州市', '信号', '有人', '成其', '推销', '方应', '688', '合同条款', '536', 'Q', '0762', '拍照', '没记', '太贵', '动态', '运', '逻辑', '从业', '定', '发不', '前置', '签订合同', 'us', '代办', '人和', '设备', '换人', '规律', '用品', '两端', '1.7', '先包', '低下', '移动网', '惠州市', '不安', '群发', '绩', '周导', '转给', '积分', '暂停', '下班', '只', '周三前', '吴伟', '711', 'es', '灰白色', '虹', '都选', '新能源', 'KEY', '单打', '街道', '艾', '346', '药膏', '全新', '案例', '录制', '96', '王先生', '063', '内', '勿扰', 'F', '回绝', '片区', '转成', '审批权', '交接', '打通', '交出来', 'NM', '列车', '收起', '移到', '317', '拦截', '缺少', '媒体业', '未上市', '先要', '备货', '声音', '此', '558', '470', '项目', 'S-', '时自', '点选', '服务期', '嘉银', '地板', '没听', '支支吾吾', '555', '很久', '招聘', '绿康', '润滑油', '黄双', '胡', '花生', '畅', '讲清楚', '翼', '使用指南', '据信', '了账', '家家', '演示', '348', '*', '取到', '一团乱', '么', '及时', '延长', '杜先生', '详细', '未来', '前台', '奔腾', '郝', '范小姐', '在线', '减低', '技术', '一早', '100', '消息', '观察', '无业', '莹莹', '转达', '标注', '67', '包装', '×', '网络界', 'SD', '上手', '儿', '刚用', '时能', '159', '范女士', '否', '看板', '满足', '金健米业', '西瓜籽', '时下', '电力工程', '科', '三九', '吉林长春', '1550', '都是考', '终端', '网', '企业应用', '青春', '健康', '行车', '来修', '秦女士', '医疗', '太远', '后安', '比较稳定', '前缀', '旧', '张一', '没有', '750', '回手', '听不见', '06023', '注', '整理', '挪', '宝', '从', '移出', '赵莉', '有间', '赔偿', '电商', '上个', '匹配', '谢先生', '内侧', '眯', '看到', '醒', '观', '左下角', '6.6', '于今', '刷新', 'ee', '代', 'ED', 'PS', '短暂', '锋', '蜜', '721', '谢女士', '面试', '夹', '要来', '周报', '转网', '报警', '高调', '希望', '达到', '放回', '成就能', '越狱', '解决问题', '付女士', '商行', '注册人', '180', '1650', '转载', '生物', '公式', '李蓉', '休眠', '不能不', '畅玩', '仁', '自由职业', '规划', '线索', '火车站', '接电', '咨询公司', '前', '行程', '华隆', '128', '电梯工', '包含', '做手', '联想', '激动', '希', '独立', 'h', '设置成', '耐尔', '确无', '更新版', 'ge', '魁', '就近', '084', '2000', '陈列', '采购单', '已经', '领', '载入', '出位', '带出', '364', '自由', '酩', '上月', '陕甘', '销售区', '本', '换新', '对', '李志', '存到', '自身', '不明', 'MB', '柳州', '姚先生', 'eq', '泰州市', '签退', '锁定', '萍', '避开', '没声', '大王', '刚', '发红', '时段', '上周', '刘振', '闭', '549', '127', '没看', '来一', '3250', '后地', '体现', '弄好', 'sina', '张亚丽', '0.00', '医', '经贸', '欧女士', 'Y', '康', '发文', '年调', '重来', '悍', '60', '民', '唐', '服务态度', '汇给', '所在地', '会歌', '糖果', '换卡', '经常性', '张勇', '打补丁', '审核员', '殊', '冯先生', '调查', '需', '力', '久', '继续', '鑫鑫', '留客', '四达', '添加', '对公', '栗', '永川', '产品名称', '恢复', '莉莉', '改名字', '自动更新', '189', '415', '呈现出', '那个', '法律', '知', '酷', '两分', '前天', '宁海', '车是', '把手', '发在', '上午', '酒类', '国平', '至', 'I', '信息沟通', '银行账号', '办理', '执行', '淮安', '罗明', '是不是', '维修', '仪', '黑龙江省', '1.2', '死活', '藏', '何时', '鸿利', '寻求', '数据流', '985', 'B', '刘红梅', 'qq', '整数', '顺发', '变化', '个人', '挑出来', 'IF', '剩下', '系', '所在', '李静', '退', '打字', '时', '总金额', '发旧', '十五', '希尔', '海明', '物流', '补签', '维', '员在', '对角', '一通', '软件所', '反应', '设置', '另外', '萨', '精', '数据表', '确实', '发布公告', '员都', '外勤人员', '调', '樊', '提示音', '不能取消', '会同', '伊', '从家', 'ea', '经开', '0011', '转正', '云上', '豹', '账号', '不到', '黄冈', '短', '服务网络', '较长', '轩', '信息内容', '707', '359', '294', '看不到', '赵女士', '源代码', '意见', '节后', '杜康', '孚', '份数', '确保', '关于', '计划外', '磨损', '501', '迈', '月中', '95', '追加', '分解', '典', '导入', '水平线上', '左上角', '都已', '想定', '累计', '黄建', '下边', '延', '罗杰', '本机', '时无', '释放', '定要', '51', '笔记本', '停止', '没签', '找错', '齐峰', '值', '甘南州', '行政区划', '停止使用', '网址', '5', '打开', '公开', '这种', '简体中文', 'MAC', '饲料', '拍好', 'bug', '16', '先试', '门客', '1860', '备份', '路径', '金贸', '采纳', '右上方', '建议人', '如下', '上方', '在手', '同意', '停机', '69', '547', '不靠', '拨', '图片格式', '还用', '不致', '查询电话', '能到', '黄', '陈惠', '必答', '姬', '没错', '117', '与否', '陈凯', '后台', '内存', '联合', '一样', '新版', '股份有限公司', '产品报价', '强烈要求', '可选择', '回来', '鲁班', '只剩', '不说', '个子', '元华', '较多', '36', '电信', '十点半', '悉', '发达', '回头', '太长', '网络', '34', '出价', '没收', '可随', '时机', '转上', '汪玲', '很困', '武', '机电', '号手', '223', '1906', '层级', '库', '回访', '韬', '只能', '协调', '濮阳市', '87', '类型', '翠翠', '京京', '莱', '衡阳', '量过大', '怎么走', '新增', '原因', '打不开', '新疆地区', '考', '错误信息', '责任', 'cg', '情绪', '安排', '采用', '新郑市', '乡镇', '立刻', '方连', '手机号码', '格洛丽亚', '522', '易先生', '体育设施', '模具厂', '用户', '612', '1800', '时进', '027', '偶然', '和易', '随机', '计算机', '三', '通考', 'W', '950', '先生', '索要', '违约' ...
# 8310

# %% [markdown]
# ## evaluate similarities

# %%
model = KeyedVectors.load_word2vec_format(cwd + 'chinese_words.txt', binary=False)

# %%
eval_words = ['网络','手机', '定位', '服务', '错误', '数据', '设置', '华为', '查看', '客户', '文件', '苹果','模块']

eval_words_map = {}

for word in eval_words:
  print(word)
  eval_words_map[word] = set(model.wv.similar_by_word(word, topn=200))
  sim_word_set = set()
  for sim_word in eval_words_map[word]:
    if sim_word[0] in word_set:
      print(sim_word)
      sim_word_set.add(sim_word[0])
  eval_words_map[word] = sim_word_set
# Out:
# 网络
# ('视频', 0.49045369029045105)
# ('用户账号', 0.4880825877189636)
# ('网络连接', 0.4905589818954468)
# ('网路', 0.5477644205093384)
# ('移动网', 0.48785609006881714)
# ('网络界', 0.506811797618866)
# ('CRM', 0.4880991280078888)
# ('互联', 0.51678466796875)
# ('QQ', 0.5266445279121399)
# 手机
# ('刷机', 0.5005427002906799)
# ('新手机', 0.5542560815811157)
# ('重拨', 0.5123473405838013)
# ('电脑', 0.5064799785614014)
# ('部手机', 0.5981699228286743)
# ('笔记本', 0.5356241464614868)
# ('平板', 0.5096657276153564)
# ('兼容问题', 0.5106188058853149)
# ('手机卡', 0.5094220638275146)
# ('诺基亚', 0.49413013458251953)
# ('移动电话', 0.5167263150215149)
# ('白屏', 0.494381308555603)
# ('机时', 0.4934317469596863)
# ('手机软件', 0.5104949474334717)
# ('PC', 0.5169134736061096)
# ('IP', 0.5196048617362976)
# ('终端', 0.5033129453659058)
# ('QQ', 0.5067571401596069)
# 定位
# ('时间轴', 0.4591441750526428)
# ('网络状', 0.4284420907497406)
# ('导入到', 0.42671823501586914)
# ('客户群', 0.43275028467178345)
# ('GPS', 0.4544619619846344)
# ('定位问题', 0.44625309109687805)
# ('WEB', 0.4273630380630493)
# ('web', 0.43357449769973755)
# 服务
# ('付款方', 0.5523066520690918)
# ('CRM', 0.5298681259155273)
# ('咨询服务', 0.5665782690048218)
# ('短信通', 0.51816326379776)
# 错误
# ('选错', 0.4570876359939575)
# ('出错', 0.47132471203804016)
# ('用错', 0.46904629468917847)
# ('正确', 0.5502479076385498)
# ('错', 0.5101631879806519)
# ('失败', 0.44337642192840576)
# ('有错', 0.4388688802719116)
# ('说错', 0.4682994484901428)
# ('有误', 0.5102933645248413)
# ('偏差', 0.4545685052871704)
# ('错误信息', 0.45625966787338257)
# ('弄错', 0.440970242023468)
# ('it', 0.44872236251831055)
# 数据
# ('数据报', 0.4638042747974396)
# ('统计数据', 0.6566974520683289)
# ('旬报', 0.4746144115924835)
# ('统计', 0.6542065143585205)
# ('栏位', 0.4559829533100128)
# ('CRM', 0.460994154214859)
# ('显示', 0.6021392345428467)
# ('数字', 0.4660318195819855)
# ('统计数字', 0.5413171052932739)
# ('数据表', 0.5455077886581421)
# ('数据量', 0.4938400387763977)
# ('薛静', 0.4573681950569153)
# ('历史数据', 0.5794025659561157)
# 设置
# ('划分', 0.47811323404312134)
# ('都设', 0.5228852033615112)
# ('设立', 0.6281454563140869)
# ('设定', 0.5406166315078735)
# ('不能取消', 0.4477936327457428)
# ('未设', 0.5048648715019226)
# ('预设', 0.4489367604255676)
# ('可设', 0.5561224222183228)
# ('弹窗', 0.46397432684898376)
# ('设为', 0.49602100253105164)
# ('设', 0.7492992877960205)
# ('没设', 0.5260223746299744)
# 华为
# ('摩托罗拉', 0.5253413915634155)
# ('中兴', 0.551406741142273)
# ('中国移动', 0.4769569933414459)
# ('诺基亚', 0.55613774061203)
# ('酷派', 0.48776406049728394)
# ('华硕', 0.4744568467140198)
# ('宇龙', 0.5434404611587524)
# ('PC', 0.4999595880508423)
# ('Sun', 0.4761351943016052)
# 查看
# ('考勤记录', 0.3924826383590698)
# ('点击', 0.4590243101119995)
# ('查找', 0.38763463497161865)
# ('询问', 0.41367316246032715)
# ('看看', 0.3788294196128845)
# ('核查', 0.4260942041873932)
# ('监控', 0.3902851641178131)
# ('联系本', 0.3592487573623657)
# ('问清', 0.3780983090400696)
# ('汇总表', 0.3694975972175598)
# ('查阅', 0.3916095793247223)
# ('详细信息', 0.3672869801521301)
# ('仔细', 0.43806666135787964)
# ('过来看', 0.3601211905479431)
# ('详细', 0.3719158470630646)
# ('地址栏', 0.3938257098197937)
# ('项目名称', 0.37409377098083496)
# ('缩略图', 0.3646506369113922)
# ('核对', 0.4147226810455322)
# ('记录表', 0.3693453371524811)
# ('检查', 0.3769535422325134)
# ('地图', 0.38296812772750854)
# ('查询', 0.3858310580253601)
# ('实时', 0.3803621530532837)
# ('具体地址', 0.3646705746650696)
# 客户
# ('工单', 0.4996006488800049)
# ('外呼', 0.5162524580955505)
# ('付款方', 0.5311623811721802)
# ('客户关系', 0.5221655368804932)
# ('客户群', 0.5847333669662476)
# ('客户地址', 0.5033901333808899)
# ('客户服务', 0.5312885642051697)
# ('员工', 0.49688440561294556)
# ('经销商', 0.5013190507888794)
# ('业务', 0.5348165035247803)
# ('老客户', 0.6177810430526733)
# ('短信通', 0.5735739469528198)
# ('服务器时', 0.5023772716522217)
# ('客户资源', 0.5442199110984802)
# ('用户', 0.5913230180740356)
# 文件
# ('程序有', 0.5043842792510986)
# ('文件类型', 0.4902721643447876)
# ('规定', 0.5189430713653564)
# ('抄送', 0.502722978591919)
# ('重要文件', 0.4935881793498993)
# ('试用版', 0.47517815232276917)
# ('会签', 0.47518813610076904)
# ('填写内容', 0.4816117286682129)
# ('收款单', 0.4855295717716217)
# ('盖公章', 0.48923224210739136)
# ('审批表', 0.4777403175830841)
# ('意见', 0.48602616786956787)
# ('数据报表', 0.4829874634742737)
# 苹果
# ('摩托罗拉', 0.5254870653152466)
# ('新手机', 0.4795107841491699)
# ('魅族', 0.5152255892753601)
# ('865', 0.4601230025291443)
# ('平板', 0.4727889895439148)
# ('苹果电脑', 0.5873993635177612)
# ('小米', 0.48749446868896484)
# ('兼容问题', 0.4846343994140625)
# ('诺基亚', 0.5404447317123413)
# ('华硕', 0.4820291996002197)
# ('Windows', 0.47752177715301514)
# ('谷歌', 0.5818961262702942)
# ('手机软件', 0.4681098461151123)
# ('微软', 0.504987359046936)
# ('开发者', 0.5119391679763794)
# ('黑莓', 0.5494090914726257)
# ('三星', 0.5066612958908081)
# ('Sun', 0.46434974670410156)
# 模块
# ('CA', 0.5570939183235168)
# ('管理器', 0.5464460849761963)
# ('功能模块', 0.5736126899719238)
# ('数据格式', 0.5347493290901184)
# ('缓存', 0.5420596599578857)
# ('CRM', 0.5559037923812866)
# ('3.0', 0.5530513525009155)
# ('系统配置', 0.5345566272735596)
# ('数据流', 0.5331461429595947)
# ('子系统', 0.5540841221809387)
# ('可编', 0.5313364267349243)

# %%
# for word in eval_words:
#   print(word)
#   dist = model.distances(word, eval_words_map[word])
#   for i in range(len(dist)):
#     print(list(eval_words_map[word])[i], dist[i])
#   print()

# %%
sim_words = ['网路', '互联', 'QQ', '部手机', '新手机', '笔记本', 
             '时间轴', 'GPS', '定位问题', '付款方', 'CRM','咨询服务', 
             '正确', '错', '有误', '统计数据', '统计', '显示',
             '设立', '设', '可设', '中兴', '宇龙', '诺基亚',
             '点击', '仔细', '核查', '客户群', '短信通','用户',
             '规定', '抄送', '程序有', '谷歌', '黑莓', '诺基亚',
             '功能模块', 'CA', 'CRM']
eval_words
# Out:
# ['网络', '手机', '定位', '服务', '错误', '数据', '设置', '华为', '查看', '客户', '文件', '苹果', '模块']

# %%
for word in eval_words:
  print(word)
  for sim in sim_words:
    print(sim, model.similarity(word, sim))
  print()
# Out:
# 网络
# 网路 0.5477645
# 互联 0.51678467
# QQ 0.5266445
# 部手机 0.21766092
# 新手机 0.29048124
# 笔记本 0.22005607
# 时间轴 0.42260474
# GPS 0.37178415
# 定位问题 0.30445313
# 付款方 0.33003592
# CRM 0.48809916
# 咨询服务 0.2239828
# 正确 0.18185362
# 错 0.13899451
# 有误 0.17791264
# 统计数据 0.183779
# 统计 0.19009843
# 显示 0.21561338
# 设立 0.20277989
# 设 0.1803557
# 可设 0.2286203
# 中兴 0.18474887
# 宇龙 0.2967091
# 诺基亚 0.27126616
# 点击 0.16547534
# 仔细 0.16047184
# 核查 0.19476423
# 客户群 0.23241821
# 短信通 0.41876405
# 用户 0.32762933
# 规定 0.21374558
# 抄送 0.21360153
# 程序有 0.3312874
# 谷歌 0.27065572
# 黑莓 0.25440145
# 诺基亚 0.27126616
# 功能模块 0.34067437
# CA 0.3264036
# CRM 0.48809916
#
# 手机
# 网路 0.27799645
# 互联 0.32165334
# QQ 0.5067572
# 部手机 0.59816986
# 新手机 0.55425614
# 笔记本 0.5356241
# 时间轴 0.35846925
# GPS 0.40034872
# 定位问题 0.2844387
# 付款方 0.39532447
# CRM 0.42827758
# 咨询服务 0.15267555
# 正确 0.106189534
# 错 0.1684431
# 有误 0.11905158
# 统计数据 0.11687635
# 统计 0.12575659
# 显示 0.16806346
# 设立 0.07833815
# 设 0.085539654
# 可设 0.2137481
# 中兴 0.29563206
# 宇龙 0.45245203
# 诺基亚 0.49413013
# 点击 0.12713341
# 仔细 0.16700518
# 核查 0.13106717
# 客户群 0.21492335
# 短信通 0.42468518
# 用户 0.36716282
# 规定 0.18485932
# 抄送 0.20300628
# 程序有 0.29911032
# 谷歌 0.33768997
# 黑莓 0.44236973
# 诺基亚 0.49413013
# 功能模块 0.32340723
# CA 0.3273552
# CRM 0.42827758
#
# 定位
# 网路 0.21219662
# 互联 0.1968242
# QQ 0.28031892
# 部手机 0.1460205
# 新手机 0.13387448
# 笔记本 0.20130873
# 时间轴 0.45914415
# GPS 0.45446196
# 定位问题 0.4462531
# 付款方 0.28099838
# CRM 0.39559314
# 咨询服务 0.19175479
# 正确 0.32329157
# 错 0.1534485
# 有误 0.10339546
# 统计数据 0.18439758
# 统计 0.22375114
# 显示 0.1375907
# 设立 0.21869677
# 设 0.17204286
# 可设 0.19459598
# 中兴 0.15542628
# 宇龙 0.29281723
# 诺基亚 0.20999455
# 点击 0.10259453
# 仔细 0.1511939
# 核查 0.1568822
# 客户群 0.43275025
# 短信通 0.2721392
# 用户 0.2802527
# 规定 0.17381419
# 抄送 0.21566465
# 程序有 0.24466744
# 谷歌 0.1738623
# 黑莓 0.17383376
# 诺基亚 0.20999455
# 功能模块 0.34370995
# CA 0.38613153
# CRM 0.39559314
#
# 服务
# 网路 0.2519971
# 互联 0.29636046
# QQ 0.39074144
# 部手机 0.20719333
# 新手机 0.18649834
# 笔记本 0.1349178
# 时间轴 0.36273003
# GPS 0.37550408
# 定位问题 0.3128161
# 付款方 0.5523067
# CRM 0.52986825
# 咨询服务 0.56657827
# 正确 0.18891555
# 错 0.13798122
# 有误 0.16236565
# 统计数据 0.22105281
# 统计 0.21750143
# 显示 0.21002838
# 设立 0.31112397
# 设 0.24895969
# 可设 0.2354906
# 中兴 0.19367813
# 宇龙 0.2848329
# 诺基亚 0.21211518
# 点击 0.11421411
# 仔细 0.10998939
# 核查 0.2579723
# 客户群 0.2937763
# 短信通 0.5181633
# 用户 0.37440106
# 规定 0.32203108
# 抄送 0.2615423
# 程序有 0.34754595
# 谷歌 0.2671514
# 黑莓 0.20344307
# 诺基亚 0.21211518
# 功能模块 0.42752463
# CA 0.40567848
# CRM 0.52986825
#
# 错误
# 网路 0.063627765
# 互联 0.13728161
# QQ 0.19093715
# 部手机 0.10165428
# 新手机 0.25918326
# 笔记本 0.15092756
# 时间轴 0.28682762
# GPS 0.19910905
# 定位问题 0.29516256
# 付款方 0.3336992
# CRM 0.26878563
# 咨询服务 0.13337302
# 正确 0.55024785
# 错 0.51016325
# 有误 0.5102934
# 统计数据 0.13168973
# 统计 0.18516387
# 显示 0.19184048
# 设立 0.08545063
# 设 0.054395135
# 可设 0.15203385
# 中兴 0.10119377
# 宇龙 0.13215955
# 诺基亚 0.1574305
# 点击 0.08982698
# 仔细 0.2205875
# 核查 0.15957701
# 客户群 0.17922771
# 短信通 0.2539245
# 用户 0.1535773
# 规定 0.25700116
# 抄送 0.26752514
# 程序有 0.43360713
# 谷歌 0.21889447
# 黑莓 0.11276004
# 诺基亚 0.1574305
# 功能模块 0.23177466
# CA 0.28408828
# CRM 0.26878563
#
# 数据
# 网路 0.2046345
# 互联 0.16068682
# QQ 0.25820804
# 部手机 0.1404927
# 新手机 0.1754774
# 笔记本 0.16449839
# 时间轴 0.31882104
# GPS 0.32855704
# 定位问题 0.27463228
# 付款方 0.28766304
# CRM 0.46099415
# 咨询服务 0.23471268
# 正确 0.1888906
# 错 0.09012456
# 有误 0.24851714
# 统计数据 0.65669733
# 统计 0.65420645
# 显示 0.60213935
# 设立 0.14016049
# 设 0.033816874
# 可设 0.17719859
# 中兴 0.20767103
# 宇龙 0.20067176
# 诺基亚 0.20288342
# 点击 0.19885527
# 仔细 0.18128936
# 核查 0.31061545
# 客户群 0.23001115
# 短信通 0.31930923
# 用户 0.3085075
# 规定 0.29483372
# 抄送 0.26958627
# 程序有 0.3172695
# 谷歌 0.24842964
# 黑莓 0.18691961
# 诺基亚 0.20288342
# 功能模块 0.34115025
# CA 0.32950974
# CRM 0.46099415
#
# 设置
# 网路 0.144352
# 互联 0.1436848
# QQ 0.26137495
# 部手机 0.14287096
# 新手机 0.05718954
# 笔记本 0.071146294
# 时间轴 0.35465166
# GPS 0.3013466
# 定位问题 0.2580175
# 付款方 0.35202277
# CRM 0.3507174
# 咨询服务 0.2739613
# 正确 0.2204674
# 错 0.19592378
# 有误 0.12787578
# 统计数据 0.13050199
# 统计 0.15595566
# 显示 0.17641416
# 设立 0.62814546
# 设 0.7492993
# 可设 0.5561224
# 中兴 0.12796624
# 宇龙 0.08229423
# 诺基亚 0.1483287
# 点击 0.14509939
# 仔细 0.15982333
# 核查 0.19612741
# 客户群 0.20454241
# 短信通 0.2931452
# 用户 0.23839505
# 规定 0.38276073
# 抄送 0.328231
# 程序有 0.41038895
# 谷歌 0.11111585
# 黑莓 0.063825384
# 诺基亚 0.1483287
# 功能模块 0.38703907
# CA 0.32326055
# CRM 0.3507174
#
# 华为
# 网路 0.17397022
# 互联 0.23295255
# QQ 0.3294823
# 部手机 0.33602104
# 新手机 0.37340474
# 笔记本 0.36916894
# 时间轴 0.24765065
# GPS 0.32550484
# 定位问题 0.31674337
# 付款方 0.24033241
# CRM 0.38208026
# 咨询服务 0.1689579
# 正确 0.11573366
# 错 0.07301013
# 有误 0.17196797
# 统计数据 0.08456781
# 统计 0.1430639
# 显示 0.15301336
# 设立 0.10450819
# 设 0.0548104
# 可设 0.1690323
# 中兴 0.55140674
# 宇龙 0.5434405
# 诺基亚 0.5561378
# 点击 0.07404723
# 仔细 0.15811855
# 核查 0.18585028
# 客户群 0.27652517
# 短信通 0.29404914
# 用户 0.27923408
# 规定 0.09464084
# 抄送 0.10323053
# 程序有 0.2651423
# 谷歌 0.379765
# 黑莓 0.39085892
# 诺基亚 0.5561378
# 功能模块 0.28457808
# CA 0.31698325
# CRM 0.38208026
#
# 查看
# 网路 0.0937766
# 互联 0.11908382
# QQ 0.20814806
# 部手机 0.13662298
# 新手机 0.099371344
# 笔记本 0.15073356
# 时间轴 0.16629492
# GPS 0.21624653
# 定位问题 0.15658996
# 付款方 0.26630217
# CRM 0.29233676
# 咨询服务 0.14872299
# 正确 0.18423004
# 错 0.12235677
# 有误 0.22623198
# 统计数据 0.17555195
# 统计 0.2610255
# 显示 0.25111315
# 设立 0.11726405
# 设 0.08227052
# 可设 0.23253697
# 中兴 0.08075686
# 宇龙 0.087118044
# 诺基亚 0.14180034
# 点击 0.4590243
# 仔细 0.43806663
# 核查 0.42609426
# 客户群 0.12130505
# 短信通 0.2503472
# 用户 0.2088625
# 规定 0.1443648
# 抄送 0.23555839
# 程序有 0.22508726
# 谷歌 0.086586684
# 黑莓 0.08435425
# 诺基亚 0.14180034
# 功能模块 0.20481521
# CA 0.19080518
# CRM 0.29233676
#
# 客户
# 网路 0.23086645
# 互联 0.23346436
# QQ 0.45526266
# 部手机 0.27383423
# 新手机 0.34180743
# 笔记本 0.23598514
# 时间轴 0.39943573
# GPS 0.31410486
# 定位问题 0.3056407
# 付款方 0.5311624
# CRM 0.47013316
# 咨询服务 0.36476892
# 正确 0.1896929
# 错 0.13931018
# 有误 0.14785755
# 统计数据 0.24698746
# 统计 0.18108562
# 显示 0.15831675
# 设立 0.20632528
# 设 0.13065867
# 可设 0.22552408
# 中兴 0.21893334
# 宇龙 0.33026767
# 诺基亚 0.21033476
# 点击 0.059397064
# 仔细 0.12484424
# 核查 0.25702387
# 客户群 0.5847334
# 短信通 0.57357395
# 用户 0.591323
# 规定 0.25545624
# 抄送 0.25770414
# 程序有 0.30941737
# 谷歌 0.28478065
# 黑莓 0.2522542
# 诺基亚 0.21033476
# 功能模块 0.38840818
# CA 0.38827235
# CRM 0.47013316
#
# 文件
# 网路 0.15344624
# 互联 0.20298994
# QQ 0.26248696
# 部手机 0.16125673
# 新手机 0.26921192
# 笔记本 0.22932029
# 时间轴 0.32041213
# GPS 0.33223465
# 定位问题 0.3247804
# 付款方 0.3681773
# CRM 0.40373498
# 咨询服务 0.23449095
# 正确 0.2446156
# 错 0.11921007
# 有误 0.27993736
# 统计数据 0.22046895
# 统计 0.22693555
# 显示 0.26901528
# 设立 0.21346061
# 设 0.101950325
# 可设 0.285054
# 中兴 0.09234037
# 宇龙 0.18958665
# 诺基亚 0.15639283
# 点击 0.12722528
# 仔细 0.19137703
# 核查 0.3716559
# 客户群 0.17219183
# 短信通 0.3743834
# 用户 0.23788568
# 规定 0.518943
# 抄送 0.5027229
# 程序有 0.5043842
# 谷歌 0.2537005
# 黑莓 0.15225194
# 诺基亚 0.15639283
# 功能模块 0.44206405
# CA 0.35553694
# CRM 0.40373498
#
# 苹果
# 网路 0.21576843
# 互联 0.20313144
# QQ 0.33963612
# 部手机 0.34196657
# 新手机 0.47951078
# 笔记本 0.4440672
# 时间轴 0.30817625
# GPS 0.31461555
# 定位问题 0.23683624
# 付款方 0.22643682
# CRM 0.36116162
# 咨询服务 0.10735647
# 正确 0.18957141
# 错 0.14969014
# 有误 0.17389156
# 统计数据 0.07324105
# 统计 0.07216932
# 显示 0.117462896
# 设立 0.11143699
# 设 0.094789915
# 可设 0.09763948
# 中兴 0.27167293
# 宇龙 0.41085702
# 诺基亚 0.54044473
# 点击 0.06864158
# 仔细 0.10148458
# 核查 0.08412799
# 客户群 0.24306054
# 短信通 0.2383881
# 用户 0.33615685
# 规定 0.18307893
# 抄送 0.11810833
# 程序有 0.26779866
# 谷歌 0.5818961
# 黑莓 0.5494091
# 诺基亚 0.54044473
# 功能模块 0.30573004
# CA 0.33386794
# CRM 0.36116162
#
# 模块
# 网路 0.23993947
# 互联 0.35918102
# QQ 0.35389727
# 部手机 0.26503497
# 新手机 0.25876963
# 笔记本 0.34748963
# 时间轴 0.47866055
# GPS 0.51520526
# 定位问题 0.2984443
# 付款方 0.3652305
# CRM 0.5559038
# 咨询服务 0.26886332
# 正确 0.2600764
# 错 0.1821587
# 有误 0.18210669
# 统计数据 0.1477898
# 统计 0.173474
# 显示 0.2190277
# 设立 0.19835448
# 设 0.23483124
# 可设 0.32338142
# 中兴 0.19503348
# 宇龙 0.32713455
# 诺基亚 0.2940959
# 点击 0.12036804
# 仔细 0.16301787
# 核查 0.2666501
# 客户群 0.2500425
# 短信通 0.32865456
# 用户 0.3645539
# 规定 0.2390504
# 抄送 0.16338971
# 程序有 0.38410282
# 谷歌 0.30370024
# 黑莓 0.2589945
# 诺基亚 0.2940959
# 功能模块 0.5736127
# CA 0.5570939
# CRM 0.5559038

# %%
from __future__ import unicode_literals, print_function, division
import pandas as pd
import os
from io import open
import glob
import unicodedata
import string
import torch
import numpy as np
import math
from nltk.tokenize import sent_tokenize, word_tokenize 
import warnings
import pickle

warnings.filterwarnings(action = 'ignore')

import gensim 
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
import gensim.downloader as api
from gensim import utils

print(gensim.__version__)
# Out:
# 3.6.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cwd = '/content/drive/My Drive/nlp_project/'

# %%
def load_embeddings(path):
    embedding_map = {}
    with open(path) as f:
        for line in f:
            try:
                pieces = line.rstrip().split()
                embedding_map[pieces[0]] = [float(weight) for weight in pieces[1:]]
            except:
                pass
    return embedding_map

def my_save_word2vec_format(fname, vocab, vectors, binary=True, total_vec=2):
    if not (vocab or vectors):
        raise RuntimeError("no input")
    if total_vec is None:
        total_vec = len(vocab)
    vector_size = vectors.shape[1]
    assert (len(vocab), vector_size) == vectors.shape
    with utils.smart_open(fname, 'wb') as fout:
        print(total_vec, vector_size)
        fout.write(utils.to_utf8("%s %s\n" % (total_vec, vector_size)))
        # store in sorted order: most frequent words at the top
        for word, row in vocab.items():
            if binary:
                row = row.astype(REAL)
                fout.write(utils.to_utf8(word) + b" " + row.tostring())
            else:
                fout.write(utils.to_utf8("%s %s\n" % (word, ' '.join(repr(val) for val in row))))

d = load_embeddings(cwd + 'sgns.sogou.bigram.txt')
print('model loaded')
m = gensim.models.keyedvectors.Word2VecKeyedVectors(vector_size=300)
m.vocab = d
m.vectors = np.array(list(d.values()))
print('write to file')
my_save_word2vec_format(binary=False, fname=cwd + 'chinese_words.txt', total_vec=len(d), vocab=m.vocab, vectors=m.vectors)
print('finish')
# Out:
# model loaded
# write to file
# 364171 300
# finish

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## get word set

# %%
data = pd.read_excel(cwd + '2018 payroll.xlsx', header = None)

# %%
print(len(data))
# Out:
# 36951

# %%
word_set = set()
for i in range(len(data)):
  situation = str(data[31][i]).split() + str(data[32][i]).split()
  for w in situation:
    word_set.add(w)
print(word_set)
print(len(word_set))
# Out:
# {'单页', 'PP', '通考', '出示', '促销员', '看', '中联', '泽', '830', '估计', '冲', '长虹', '描述', '关于', '111', '个字符', '发展', '804', '个例', '剩', '县城', '中下', '微云', '15万', '返回', 'LA', '730', '冠', '路线', '表述', '内侧', '五一节', '周口', '出差', '分配', '下属', '常发', '观海', '不停', '锦州', '具体内容', '跟上', '345', '说不清楚', '送货', '售价', '重复', '建', '根', '金立', '骂', '天水市', '影响', '电瓶', '吉林省', '痴呆', '发发', '靠谱', '宣讲', '没关', '经销商', '报销', '咨询员', '拼音', '时尚', '再次出现', '母女', '1887', '端', '待审', '遵义', '2014', '很早', '接电话', '询问', '袁浩', '耗费', '绿色', '序', '开关', '换位', '回手', '玩', '郭爽', '欧阳', '您', '每月', '汪玉', '文档', '养护', '常用', '量过大', '并', '报', 'st', '刚用', '第', '周五', '大格局', '策划', '转回', '缺少', '536', 'xp', '市里', '叱', '张爱', '季度', '新乡市', '地址', '唐盛', '光电', '经', '由', '侯女士', '进在', '为人', '人定', '电脑操作', '昊', '宜静', '白纸黑字', '插入', '洁', '加到', '阶段', '交尾', '九', '天下', '538', '显', '以使', '拨', '全天', '没测', '马女士', '123', '谱', '体型', '临时', '想开', '熟悉', '萍', '秦', '再加', '源', '故障', '贵阳市', 'it', '293', '想尽', '机电工程', '龙翔', 'C', '免费', '要账', '家教', '赞', '题图', '进不了', '泰州市', '王慧', '王亚', '涂', '加人', '有异', '咚', '会通', '取到', 'cm', '公章', '珍', '动', '滨州市', '551', '解锁', '制品', '不畅', '50万', '一切正常', '蚌埠市', '112', '部分', '中心', '1350', '群发', 'PS', '仲先生', '天瑞', '进度', '跑回', 'MM', '意思', '豆', '排班', '高级', '和安', '对外', '德昌', '都认', '指纹', '仁寿', '郭', '列有', '130', '这样的话', '据', '启用', '偏', '大地', '最高级别', '企业数', '庾', '逻辑', '后会', '彤', '里水', 't', 'cg', '小一', '店里', '426', '翼', '店', '台报', '应用程序', '不关', '断开', '各自', '即', '没准', '条款', '不存', '熙', 'as', '交汇', '两手', '崔先生', '饶先生', '全立', '法院', '杏', '已有', '海达', '在后', '冻品', '德隆', '中听', '因为', '朱文', '江月', '中加', 'OK', '在手', '阿婆', '未及', '了了', '侨', '南区', '极速', '依法', '先包', '比较忙', '云上', '预付款', '按着', '块', '各种', '准确', '收取', '功', '恩', '电池', '407', '时就会', 'ss', '朗', '造成了', '证照', '清客', 'ps', '远程', '内部', '---', '沈阳', '说是', '相信', '流失', '通商', '小李', '后记', '张亚丽', '通电子', '有时候', '杀死', '看不见', '1946', '当中', '工程部', '主管', '千米', '作弊', '组人', '家里', '袁经理', '中客', '较远', '最高', '通过', '在线', '项目', '北京南站', '行驶', '教育科', '提高', '不升', '时跟', '格', '05', '知晓', '......', '2013', '334', '盘', '隔', '身份证号', '慢慢', '新的', '不安', '日期', '语言', '集成电路', '汪军', '时用', '此类', '没通', '存在', '断断续续', '橱柜', 'sina', '志', '订阅', '544', '黄宇', '从来没', '脾气', '发送信息', '中科', '未交', '筵', '宏', '刚说', '岗位', '加速', '单打', '做好', '完成率', '很久没', '两端', '该部', '区分', '263', '唯一', '有没有', 'PC', '不卖', '中地', '发起', '组里', '型', '下同', '减低', '于', '如有', '发现', '浩', 'im', '1040', '断线', '年过', '之后', '295', '互换', '下不来', '都是没', '何先生', '不到', '388', '同级', '霞云', '未处理', '分享', '上海浦东', '54', '只需', '管业', '有错', '每一次', '52', '交完', '前边', '吃饭时间', '化', '刷', '定时', '法务部', '想', '全面', '删', '降到', '白城', '无须', '宁都县', '范小姐', '签退', '骗子', '二十', '朵', '寻求', '592', '哈', '成英', '科瑞', '自己', '清晰', '修改', '结束', '勾选', '老是', '部署', '药业', '在任', '哀', '专属', '冶金', '身边', '教', '其一', '167', '铁', '794', '秦女士', '来分', '迅', '听不清', '过程', '电梯', '204', '万嘉', '发手机', '版块', '搜', '反映', '鹤壁市', '定在', '337', '晚会', '431', '古都', '西林', '必达', '院长', '都是我', '长风', '186', '周二', '事情', '您好', '658', '转网', '385', '崔', '管部', '刘文', '清理', '右下', '打错', '金豆豆', '准备', '1999', '张敏', '违规行为', '注销', '沪', '走', '吧', '2020', '获取', '选', '顺', '要用', '蓝点', '察觉', '确认', '辣', '厚和', '台', '供', '武女士', '475', '聚', '中出', '389', '少是', '录音', '上市', 'px', '留客', '400', '说定', '免费版', '初始', '驳回', '信息管理', '鲁', '薛', '较长', '创建人', '二维码', '242', '安时', '发文件', '0.1', '特殊', '汉字', '下次', '吴先生', '347', 'l', '乳业', '丁贺', '55', '米是', '不会', '外面', '变形', '姚先生', '再拜', '161', '电气', '道出', '刚改', '秘', '在职人员', '洪先生', '并未', '赵女士', '284', '马上', '没规矩', '女朋友', '加过', '太多', '宠', '50', '创新', '李仕', '记得', '教育培训', '早起', '修改版', 'tnt', '输', '销售业', '琼', '问到', '3.2', '业务人员', '6.2', '五粮', '设', '加盟费', '漂', '通病', '道石', '说不清', '百分百', '花生', 'Windows', '退款', '494', '赣州', '操作步骤', '执行人', '较差', '157', '凯', '胡佳', '杨女士', '费是', '改变', '期会', '冯女士', '标题', '罗星', '时所', '中心点', '商贸', '60', '参照', '加紧', '1888', '时一', '不够', '密匙', '符合规定', '一级', '调式', '麒麟', '休眠', '中部', '偿', '范女士', '不限', '再登', ',', '几张', '请假', '分之', '改号', '1861', '成就能', '整一', '哪些', '306', '月底', 'f', '未查', '电商', '六安', '对工', '视', '很高', '可', '存正', '未留', '提起', '斯', '数显', '吴伟', '85', '出位', '来问', '纠结', '86', '四十', '让', '版本', '照', '维诺',  ...
# 8310

# %% [markdown]
# ## evaluate similarities

# %%
model = KeyedVectors.load_word2vec_format(cwd + 'chinese_words.txt', binary=False)

# %%
eval_words = ['网络','手机', '定位', '服务', '错误', '数据', '锤子', '设置', '华为', '查看', '客户', '文件', '苹果','模块']

eval_words_map = {}

for word in eval_words:
  print(word)
  eval_words_map[word] = set(model.wv.similar_by_word(word, topn=200))
  sim_word_set = set()
  for sim_word in eval_words_map[word]:
    if sim_word[0] in word_set:
      print(sim_word)
      sim_word_set.add(sim_word[0])
  eval_words_map[word] = sim_word_set
# Out:
# 网络
# ('网络连接', 0.4905589818954468)
# ('网路', 0.5477644205093384)
# ('QQ', 0.5266445279121399)
# ('视频', 0.49045369029045105)
# ('用户账号', 0.4880825877189636)
# ('网络界', 0.506811797618866)
# ('互联', 0.51678466796875)
# ('CRM', 0.4880991280078888)
# ('移动网', 0.48785609006881714)
# 手机
# ('笔记本', 0.5356241464614868)
# ('移动电话', 0.5167263150215149)
# ('刷机', 0.5005427002906799)
# ('机时', 0.4934317469596863)
# ('QQ', 0.5067571401596069)
# ('兼容问题', 0.5106188058853149)
# ('IP', 0.5196048617362976)
# ('白屏', 0.494381308555603)
# ('重拨', 0.5123473405838013)
# ('电脑', 0.5064799785614014)
# ('手机软件', 0.5104949474334717)
# ('诺基亚', 0.49413013458251953)
# ('终端', 0.5033129453659058)
# ('PC', 0.5169134736061096)
# ('手机卡', 0.5094220638275146)
# ('新手机', 0.5542560815811157)
# ('平板', 0.5096657276153564)
# ('部手机', 0.5981699228286743)
# 定位
# ('web', 0.43357449769973755)
# ('GPS', 0.4544619619846344)
# ('WEB', 0.4273630380630493)
# ('客户群', 0.43275028467178345)
# ('时间轴', 0.4591441750526428)
# ('网络状', 0.4284420907497406)
# ('定位问题', 0.44625309109687805)
# ('导入到', 0.42671823501586914)
# 服务
# ('咨询服务', 0.5665782690048218)
# ('短信通', 0.51816326379776)
# ('CRM', 0.5298681259155273)
# ('付款方', 0.5523066520690918)
# 错误
# ('选错', 0.4570876359939575)
# ('错', 0.5101631879806519)
# ('出错', 0.47132471203804016)
# ('弄错', 0.440970242023468)
# ('错误信息', 0.45625966787338257)
# ('有误', 0.5102933645248413)
# ('说错', 0.4682994484901428)
# ('失败', 0.44337642192840576)
# ('it', 0.44872236251831055)
# ('偏差', 0.4545685052871704)
# ('用错', 0.46904629468917847)
# ('有错', 0.4388688802719116)
# ('正确', 0.5502479076385498)
# 数据
# ('统计数字', 0.5413171052932739)
# ('数据表', 0.5455077886581421)
# ('数据报', 0.4638042747974396)
# ('历史数据', 0.5794025659561157)
# ('薛静', 0.4573681950569153)
# ('统计数据', 0.6566974520683289)
# ('统计', 0.6542065143585205)
# ('旬报', 0.4746144115924835)
# ('数字', 0.4660318195819855)
# ('CRM', 0.460994154214859)
# ('显示', 0.6021392345428467)
# ('栏位', 0.4559829533100128)
# ('数据量', 0.4938400387763977)
# 锤子
# ('钉钉', 0.5636367201805115)
# 设置
# ('都设', 0.5228852033615112)
# ('可设', 0.5561224222183228)
# ('划分', 0.47811323404312134)
# ('弹窗', 0.46397432684898376)
# ('预设', 0.4489367604255676)
# ('设为', 0.49602100253105164)
# ('没设', 0.5260223746299744)
# ('设', 0.7492992877960205)
# ('不能取消', 0.4477936327457428)
# ('未设', 0.5048648715019226)
# ('设立', 0.6281454563140869)
# ('设定', 0.5406166315078735)
# 华为
# ('中兴', 0.551406741142273)
# ('宇龙', 0.5434404611587524)
# ('中国移动', 0.4769569933414459)
# ('酷派', 0.48776406049728394)
# ('华硕', 0.4744568467140198)
# ('摩托罗拉', 0.5253413915634155)
# ('诺基亚', 0.55613774061203)
# ('PC', 0.4999595880508423)
# ('Sun', 0.4761351943016052)
# 查看
# ('项目名称', 0.37409377098083496)
# ('查询', 0.3858310580253601)
# ('联系本', 0.3592487573623657)
# ('地图', 0.38296812772750854)
# ('点击', 0.4590243101119995)
# ('详细信息', 0.3672869801521301)
# ('询问', 0.41367316246032715)
# ('仔细', 0.43806666135787964)
# ('详细', 0.3719158470630646)
# ('核对', 0.4147226810455322)
# ('汇总表', 0.3694975972175598)
# ('查找', 0.38763463497161865)
# ('查阅', 0.3916095793247223)
# ('具体地址', 0.3646705746650696)
# ('记录表', 0.3693453371524811)
# ('看看', 0.3788294196128845)
# ('监控', 0.3902851641178131)
# ('检查', 0.3769535422325134)
# ('问清', 0.3780983090400696)
# ('地址栏', 0.3938257098197937)
# ('过来看', 0.3601211905479431)
# ('核查', 0.4260942041873932)
# ('缩略图', 0.3646506369113922)
# ('考勤记录', 0.3924826383590698)
# ('实时', 0.3803621530532837)
# 客户
# ('客户地址', 0.5033901333808899)
# ('工单', 0.4996006488800049)
# ('客户资源', 0.5442199110984802)
# ('客户群', 0.5847333669662476)
# ('员工', 0.49688440561294556)
# ('老客户', 0.6177810430526733)
# ('短信通', 0.5735739469528198)
# ('客户关系', 0.5221655368804932)
# ('外呼', 0.5162524580955505)
# ('客户服务', 0.5312885642051697)
# ('经销商', 0.5013190507888794)
# ('服务器时', 0.5023772716522217)
# ('付款方', 0.5311623811721802)
# ('业务', 0.5348165035247803)
# ('用户', 0.5913230180740356)
# 文件
# ('收款单', 0.4855295717716217)
# ('规定', 0.5189430713653564)
# ('抄送', 0.502722978591919)
# ('盖公章', 0.48923224210739136)
# ('填写内容', 0.4816117286682129)
# ('数据报表', 0.4829874634742737)
# ('文件类型', 0.4902721643447876)
# ('试用版', 0.47517815232276917)
# ('审批表', 0.4777403175830841)
# ('程序有', 0.5043842792510986)
# ('重要文件', 0.4935881793498993)
# ('意见', 0.48602616786956787)
# ('会签', 0.47518813610076904)
# 苹果
# ('谷歌', 0.5818961262702942)
# ('黑莓', 0.5494090914726257)
# ('兼容问题', 0.4846343994140625)
# ('Windows', 0.47752177715301514)
# ('华硕', 0.4820291996002197)
# ('三星', 0.5066612958908081)
# ('摩托罗拉', 0.5254870653152466)
# ('手机软件', 0.4681098461151123)
# ('开发者', 0.5119391679763794)
# ('小米', 0.48749446868896484)
# ('诺基亚', 0.5404447317123413)
# ('865', 0.4601230025291443)
# ('Sun', 0.46434974670410156)
# ('新手机', 0.4795107841491699)
# ('微软', 0.504987359046936)
# ('平板', 0.4727889895439148)
# ('魅族', 0.5152255892753601)
# ('苹果电脑', 0.5873993635177612)
# 模块
# ('缓存', 0.5420596599578857)
# ('CA', 0.5570939183235168)
# ('数据格式', 0.5347493290901184)
# ('数据流', 0.5331461429595947)
# ('子系统', 0.5540841221809387)
# ('可编', 0.5313364267349243)
# ('系统配置', 0.5345566272735596)
# ('CRM', 0.5559037923812866)
# ('3.0', 0.5530513525009155)
# ('功能模块', 0.5736126899719238)
# ('管理器', 0.5464460849761963)

# %%
for word in eval_words:
  print(word)
  dist = model.distances(word, eval_words_map[word])
  for i in range(len(dist)):
    print(list(eval_words_map[word])[i], dist[i])
  print()
# Out:
# 网络
# QQ 0.4733554
# 网络界 0.4931882
# 视频 0.5095462
# 用户账号 0.5119174
# CRM 0.5119009
# 互联 0.48321533
# 移动网 0.51214385
# 网络连接 0.509441
# 网路 0.45223558
#
# 手机
# 重拨 0.48765278
# 手机软件 0.4895051
# 笔记本 0.46437585
# QQ 0.49324286
# 刷机 0.49945736
# 电脑 0.49352008
# 平板 0.49033433
# 机时 0.5065683
# 移动电话 0.48327363
# 兼容问题 0.48938125
# 手机卡 0.49057788
# 白屏 0.5056187
# 部手机 0.40183026
# 新手机 0.44574398
# 终端 0.49668705
# PC 0.48308653
# 诺基亚 0.50586987
# IP 0.48039508
#
# 定位
# 时间轴 0.5408558
# 定位问题 0.55374694
# 网络状 0.57155794
# 导入到 0.57328176
# WEB 0.57263696
# GPS 0.54553807
# web 0.5664255
# 客户群 0.5672498
#
# 服务
# 短信通 0.48183674
# 付款方 0.44769323
# 咨询服务 0.43342173
# CRM 0.47013187
#
# 错误
# it 0.55127764
# 说错 0.53170055
# 偏差 0.5454315
# 选错 0.5429124
# 用错 0.53095376
# 有错 0.5611312
# 弄错 0.5590298
# 失败 0.5566236
# 错 0.4898368
# 出错 0.52867526
# 正确 0.44975203
# 有误 0.48970658
# 错误信息 0.5437404
#
# 数据
# 数据报 0.5361957
# 统计数字 0.4586829
# 旬报 0.5253856
# 数字 0.5339682
# 栏位 0.5440171
# 数据量 0.50616
# 统计 0.3457935
# 统计数据 0.34330255
# 薛静 0.54263175
# 显示 0.3978607
# 历史数据 0.42059743
# CRM 0.5390059
# 数据表 0.4544922
#
# 锤子
# 钉钉 0.43636328
#
# 设置
# 划分 0.5218867
# 设定 0.45938337
# 弹窗 0.53602564
# 设 0.2507007
# 都设 0.4771148
# 设为 0.50397897
# 不能取消 0.5522064
# 预设 0.5510633
# 未设 0.4951352
# 可设 0.44387752
# 没设 0.47397763
# 设立 0.37185448
#
# 华为
# 摩托罗拉 0.4746586
# 宇龙 0.45655954
# 中兴 0.44859326
# 华硕 0.52554315
# 酷派 0.512236
# PC 0.5000405
# 中国移动 0.52304304
# Sun 0.5238648
# 诺基亚 0.4438622
#
# 查看
# 实时 0.61963785
# 汇总表 0.63050234
# 核查 0.57390577
# 项目名称 0.6259062
# 核对 0.5852773
# 记录表 0.6306547
# 询问 0.58632684
# 查找 0.61236537
# 点击 0.54097575
# 考勤记录 0.6075174
# 检查 0.6230465
# 查阅 0.60839033
# 详细信息 0.6327131
# 具体地址 0.6353294
# 过来看 0.6398788
# 仔细 0.56193334
# 监控 0.60971487
# 地址栏 0.6061743
# 看看 0.6211705
# 地图 0.6170318
# 查询 0.614169
# 联系本 0.6407512
# 详细 0.6280842
# 缩略图 0.6353494
# 问清 0.62190175
#
# 客户
# 外呼 0.4837476
# 员工 0.50311565
# 经销商 0.49868095
# 客户地址 0.49660987
# 短信通 0.4264261
# 付款方 0.46883768
# 用户 0.40867704
# 业务 0.46518356
# 客户资源 0.4557801
# 服务器时 0.4976228
# 老客户 0.38221896
# 客户服务 0.4687115
# 工单 0.5003995
# 客户关系 0.47783446
# 客户群 0.41526663
#
# 文件
# 试用版 0.5248219
# 文件类型 0.50972795
# 意见 0.51397383
# 程序有 0.49561578
# 重要文件 0.50641185
# 规定 0.48105705
# 收款单 0.51447046
# 填写内容 0.5183883
# 会签 0.52481186
# 抄送 0.49727702
# 盖公章 0.51076776
# 审批表 0.5222597
# 数据报表 0.5170126
#
# 苹果
# 手机软件 0.53189015
# 三星 0.4933387
# 谷歌 0.4181038
# 黑莓 0.4505909
# 摩托罗拉 0.47451293
# 新手机 0.5204892
# 微软 0.49501264
# 平板 0.52721107
# 开发者 0.48806083
# 兼容问题 0.5153657
# 小米 0.51250553
# 苹果电脑 0.41260064
# 865 0.53987694
# 华硕 0.5179708
# Sun 0.53565025
# 魅族 0.4847744
# Windows 0.5224782
# 诺基亚 0.45955527
#
# 模块
# 子系统 0.44591588
# 3.0 0.4469486
# 功能模块 0.42638737
# CA 0.44290614
# 缓存 0.45794034
# 系统配置 0.46544337
# 数据流 0.4668538
# 管理器 0.45355392
# 可编 0.46866357
# CRM 0.4440962
# 数据格式 0.46525073

# %%
with open(cwd + 'tokenized_word_set.pickle', 'rb') as f:
    word_set = pickle.load(f)

# %%
print(type(word_set))
# Out:
# <class 'set'>
